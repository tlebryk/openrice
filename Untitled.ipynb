# %%
import pandas as pd
from utils.s3utils import read_key_dflist

# %%
ls = read_key_dflist(r"data/shop_meta")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-b9d9e2f7120d> in <module>
# ----> 1 ls = read_key_dflist(r"data/shop_meta")
#
# c:\Users\tlebr\OneDrive - pku.edu.cn\China in Transition\openrice\utils\s3utils.py in read_key_dflist(filedir, client, filepattern, bucket, quiet, min_page)
#      72                     logging.info(f"Reading in {key} from S3")
#      73                 file_body = client.get_object(Bucket=bucket, Key=key).get('Body')
# ---> 74                 df = pd.read_json(io.BytesIO(file_body.read()), lines=True)
#      75                 logging.info(f"adding {key} to file_ls")
#      76                 outlist.append((key, df))
#
# ~\envs\openrice\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# ...

# %%
for k, df in ls:
    filename = k.split("/")[-1]
    print(filename)

# %%
df = pd.read_json("aust.json")

# %%
newblue = pd.read_csv(r"C:\Users\tlebr\OneDrive - pku.edu.cn\China in Transition\openrice\data\blue_eat_0_None.csv")
oldblue = pd.read_csv(r"C:\Users\tlebr\OneDrive - pku.edu.cn\China in Transition\openrice\data\shop_meta\blue_eat\20210702\blue_eat_0_None.csv")

# %%
newblue.sort_values("id")
# Out:
#       Unnamed: 0    id                                       original_url  \
# 0              0   215       https://s.openrice.com/QrbS0HQ0700~dfFvOE8UE
# 1              1   216       https://s.openrice.com/QrbS0nMS800~doI7kMWdh
# 2              2   217       https://s.openrice.com/QrbS05v0900~doI7kMWdh
# 3              3   218       https://s.openrice.com/QrbS0S2O900~doI7kMWdh
# 4              4   219       https://s.openrice.com/QrbS00zW4W0~doI7kMWdh
# ...          ...   ...                                                ...
# 1873        1873  2248  https://www.openrice.com/zh/hongkong/r-%E9%BE%...
# 1874        1874  2249  https://www.openrice.com/zh/hongkong/r-%E9%BE%...
# 1879        1879  2251                 https://s.openrice.com/QrbS03rSA00
# 1880        1880  2252                 https://s.openrice.com/QrbS0XT0900
# 1881        1881  2253                 https://s.openrice.com/QrbS0zlY4W0
#
#               scrape_time                     title_main title_add  \
# ...

# %%
oldblue.sort_values("id")
# Out:
#         id                                       original_url  \
# 7      215       https://s.openrice.com/QrbS0HQ0700~dfFvOE8UE
# 5      216       https://s.openrice.com/QrbS0nMS800~doI7kMWdh
# 0      217       https://s.openrice.com/QrbS05v0900~doI7kMWdh
# 17     218       https://s.openrice.com/QrbS0S2O900~doI7kMWdh
# 6      219       https://s.openrice.com/QrbS00zW4W0~doI7kMWdh
# ...    ...                                                ...
# 1869  2248  https://www.openrice.com/zh/hongkong/r-%E9%BE%...
# 1867  2249  https://www.openrice.com/zh/hongkong/r-%E9%BE%...
# 1884  2251                 https://s.openrice.com/QrbS03rSA00
# 1883  2252                 https://s.openrice.com/QrbS0XT0900
# 1870  2253                 https://s.openrice.com/QrbS0zlY4W0
#
#                      scrape_time                     title_main title_add  \
# 7     2021-07-02 10:22:21.848838                           #OMG  (Closed)
# ...

# %%
def s(x):
    return "\n".join([e.strip() for e in x])
df.body = df['body'].transform(lambda x: s(x))

# %%
df.head()
# Out:
#    total_reviews  a_plus       username   grade  \
# 0             53       0    joannaleehy  Level3
# 1              5       0     ciwaja7544  Level2
# 2             90       0        Sukycoy  Level3
# 3             11       0  leogirl.hk852  Level2
# 4             28       0         cx7614  Level2
#
#                                      user_link  \
# 0  /en/restaurant/userinfo.htm?userid=64638191
# 1  /en/restaurant/userinfo.htm?userid=67104936
# 2  /en/restaurant/userinfo.htm?userid=64481181
# 3  /en/restaurant/userinfo.htm?userid=67107231
# 4    /en/restaurant/userinfo.htm?userid=863041
#
#                                                emoji       date  viewcount  \
# 0  icon or-sprite-inline-block common_smiley_smil... 2021-03-21  237 views
# 1                                               None 2021-03-12  280 views
# 2  icon or-sprite-inline-block common_smiley_smil... 2021-02-22  456 views
# 3                                               None 2021-03-14  298 views
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import six

# df = pd.DataFrame()
# df['date'] = ['2016-04-01', '2016-04-02', '2016-04-03']
# df['calories'] = [2200, 2100, 1500]
# df['sleep hours'] = [2200, 2100, 1500]
# df['gym'] = [True, False, False]


def render_mpl_table(data, col_width=3.0, row_height=0.625, font_size=14,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')

    mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)

    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in  six.iteritems(mpl_table._cells):
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax

render_mpl_table(df.drop(["body", "username", "Recommended Dishes"], axis=1), header_columns=0, col_width=2.0)
# Out:
# <AxesSubplot:>

# %%
df.to_csv('aust_edited.csv', index=False)
